# %% [markdown]
# <a href="https://colab.research.google.com/github/adiban17/Deep-Learning-Models/blob/main/CNN_Stacking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing the Dataset and Data Augmentation**

# %% [markdown]
# ### **Filtering Warnings**

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### **Importing the Dataset**

# %%
# !unzip -q "/content/drive/MyDrive/NPTEL : Foundations of Deep Learning Concepts and Applications (Datasets)/alzheimer dataset_2.zip" -d /content/dataset_local

# %%
# !ls -lh /content/dataset_local
# Out:
# total 8.0K
# drwxr-xr-x 4 root root 4.0K May 25 20:51 'alzheimer dataset'
# drwxr-xr-x 3 root root 4.0K Jun  1 18:04  __MACOSX

# %% [markdown]
# #### **Data Augmentation**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Paths to the data
train_dir = '/content/dataset_local/alzheimer dataset/train'
test_dir = '/content/dataset_local/alzheimer dataset/test'

train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.4,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(
    rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    color_mode='grayscale',
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(128, 128),
    color_mode='grayscale',
    class_mode='categorical'
)

n_classes = 4
input_shape = (128, 128, 1)
# Out:
# Found 4647 images belonging to 4 classes.
# Found 1230 images belonging to 4 classes.

# %% [markdown]
# # **Build 3 CNN Models**

# %%
# importing all necessary libraries

import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import BatchNormalization

# %% [markdown]
# ## **Base CNN Models**

# %% [markdown]
# ### **CNN Model 1**

# %%
CNN1 = Sequential()
CNN1.add(Conv2D(filters=256, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
CNN1.add(MaxPooling2D(pool_size=(2, 2)))

CNN1.add(Conv2D(64, (3, 3), activation='relu'))
CNN1.add(MaxPooling2D(pool_size=(2, 2)))

CNN1.add(Conv2D(filters=256, kernel_size=(3, 3), activation='relu'))
CNN1.add(MaxPooling2D(pool_size=(2, 2)))

CNN1.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
CNN1.add(MaxPooling2D(pool_size=(2, 2)))

CNN1.add(Conv2D(filters=256, kernel_size=(3, 3), activation='relu'))
CNN1.add(MaxPooling2D(pool_size=(2, 2)))

CNN1.add(Flatten())
CNN1.add(Dense(units=128, activation='relu'))
CNN1.add(Dropout(0.2))
CNN1.add(Dense(units=64, activation='relu'))
CNN1.add(Dropout(0.2))
CNN1.add(Dense(units=n_classes, activation='softmax'))

CNN1.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

CNN1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 256)  │         2,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │       147,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 256)    │       147,712 │
# ...

# %%
CNN1.fit(train_generator, epochs=50)
# Out:
# Epoch 1/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 30s 121ms/step - accuracy: 0.5851 - loss: 1.0019
# Epoch 2/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.5877 - loss: 0.9039
# Epoch 3/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.6025 - loss: 0.8399
# Epoch 4/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.6185 - loss: 0.8049
# Epoch 5/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 85ms/step - accuracy: 0.6288 - loss: 0.7791
# Epoch 6/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.6572 - loss: 0.7592
# Epoch 7/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 20s 83ms/step - accuracy: 0.6615 - loss: 0.7353
# Epoch 8/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.6845 - loss: 0.7130
# Epoch 9/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.6755 - loss: 0.6918
# Epoch 10/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 79ms/step - accuracy: 0.6972 - loss: 0.6604
# Epoch 11/50
# ...

# %% [markdown]
# #### **Evaluation**

# %%
loss, accuracy = CNN1.evaluate(test_generator)
print(f"Accuracy:{accuracy}\nLoss:{loss}")
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.9382 - loss: 0.1519
# Accuracy:0.9382113814353943
# Loss:0.15194202959537506

# %% [markdown]
# ### **CNN Model 2**

# %%
CNN2 = Sequential([

    Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape),
    BatchNormalization(),
    Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),

    Dense(units=256, activation='relu'),
    Dropout(0.4),
    Dense(units=128, activation='relu'),
    Dropout(0.3),
    Dense(units=n_classes, activation='softmax')
])

CNN2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

CNN2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)               │ (None, 128, 128, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 128, 128, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
CNN2.fit(train_generator, epochs=50, validation_data=test_generator)
# Out:
# Epoch 1/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 46s 193ms/step - accuracy: 0.5653 - loss: 1.1657 - val_accuracy: 0.3756 - val_loss: 1.3153
# Epoch 2/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.5918 - loss: 0.8704 - val_accuracy: 0.3756 - val_loss: 1.2743
# Epoch 3/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 93ms/step - accuracy: 0.6118 - loss: 0.8501 - val_accuracy: 0.4049 - val_loss: 1.1934
# Epoch 4/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 93ms/step - accuracy: 0.6187 - loss: 0.8150 - val_accuracy: 0.4390 - val_loss: 1.2143
# Epoch 5/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 93ms/step - accuracy: 0.6170 - loss: 0.8133 - val_accuracy: 0.6837 - val_loss: 0.9137
# Epoch 6/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.6365 - loss: 0.7981 - val_accuracy: 0.4276 - val_loss: 1.3510
# Epoch 7/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 93ms/step - accuracy: 0.6374 - loss: 0.7944 - val_accuracy: 0.6951 - val_loss: 0.8956
# Epoch 8/50
# ...

# %%
loss, accuracy = CNN2.evaluate(test_generator)
print(f"Accuracy:{accuracy}\nLoss:{loss}")
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7618 - loss: 0.5780
# Accuracy:0.7617886066436768
# Loss:0.5779555439949036

# %% [markdown]
# ### **CNN Model 3**

# %%
CNN3 = Sequential([
    Conv2D(filters=32, kernel_size=(5, 5), activation='relu', padding='same', input_shape=input_shape),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),

    Dense(units=128, activation='relu'),
    Dropout(0.5),
    Dense(units=n_classes, activation='softmax')
])

CNN3.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

CNN3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_15 (Conv2D)              │ (None, 128, 128, 32)   │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 32, 32, 128)    │        73,856 │
# ...

# %%
CNN3.fit(test_generator, epochs=50)
# Out:
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 11s 115ms/step - accuracy: 0.6724 - loss: 0.9450
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8431 - loss: 0.4777
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8512 - loss: 0.4326
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8650 - loss: 0.3752
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8878 - loss: 0.3023
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9187 - loss: 0.2334
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9463 - loss: 0.1577
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9675 - loss: 0.0999
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9537 - loss: 0.1188
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9764 - loss: 0.0743
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9894 - loss: 0.0320
# Epoch 12/50
# ...

# %%
loss, acc = CNN3.evaluate(test_generator)
print(f"Accuracy:{acc}\nLoss:{loss}")
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 1.7903e-04
# Accuracy:1.0
# Loss:0.00017903481784742326

# %% [markdown]
# ### **Stacking the 3 CNNs**

# %%
'''
TO freeze the first-level CNN models so that during the second-level training:
only the MLP_meta (second-level model) learns. The CNNs do not get updated again.
This is the correct stacking behavior.
'''

from tensorflow.keras.layers import Input, Concatenate
from tensorflow.keras.models import Model

for base_model in [CNN1, CNN2, CNN3]:
  base_model.trainable = False

# Shared Input
stack_input = Input(shape=input_shape)

# Get softmax outputs from each base model
pred1 = CNN1(stack_input)
pred2 = CNN2(stack_input)
pred3 = CNN3(stack_input)

# Concatenate predictions -> meta-features
merged = Concatenate()([pred1, pred2, pred3])

meta_input_dim = 3 * n_classes

MLP_meta = Sequential(name='mlp_meta')
MLP_meta.add(Dense(32, activation='relu'))
MLP_meta.add(Dense(32, activation='relu'))
MLP_meta.add(Dropout(0.5))
MLP_meta.add(Dense(n_classes, activation='softmax'))

# Pass merged predictions tp MLP_meta
stack_output = MLP_meta(merged)

# Final stacking model
Stacking_Model = Model(inputs=stack_input, outputs=stack_output)

Stacking_Model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

Stacking_Model.summary()
# Out:
# Model: "functional_20"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 4)         │  1,027,716 │ input_layer_8[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_1        │ (None, 4)         │ 17,365,828 │ input_layer_8[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
Stacking_Model.fit(
    train_generator,
    epochs=3,
    validation_data=test_generator
)
# Out:
# Epoch 1/3
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 85ms/step - accuracy: 0.9359 - loss: 0.2263 - val_accuracy: 0.9504 - val_loss: 0.1532
# Epoch 2/3
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.9359 - loss: 0.2220 - val_accuracy: 0.9472 - val_loss: 0.1644
# Epoch 3/3
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 79ms/step - accuracy: 0.9430 - loss: 0.1978 - val_accuracy: 0.9512 - val_loss: 0.1507

# %%
loss, acc = Stacking_Model.evaluate(test_generator)
print(f"Accuracy:{acc}\nLoss:{loss}")
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9512 - loss: 0.1507
# Accuracy:0.9512194991111755
# Loss:0.1506882905960083
